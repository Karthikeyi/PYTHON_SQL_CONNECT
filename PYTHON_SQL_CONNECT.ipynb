# %%
import json
import pandas as pd

# %%
#reading Customer Data
df1=pd.read_json('C:/Users/karth/OneDrive/Desktop/REV_PROJECTS/DataSets/customers.json')
print(df1)
print(type(df1))
# Out:
#      customer_id     customer_name      country           city
# 0           9780      Jessica Hart   Martinique  South William
# 1           9169         Amy Clark   Kazakhstan     Davisville
# 2           6631  Danielle Elliott      Armenia     East Danny
# 3           8772     Robin Mendoza       Uganda    Johnsonbury
# 4           8913    Abigail Miller      Namibia  Wrightchester
# ..           ...               ...          ...            ...
# 995         6357    Jessica Castro     Dominica     Deannastad
# 996          244    Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490   Luis Strickland        Italy     Oneilltown
# 998         2984    Jennifer Kelly      Bahamas    Xavierville
# 999         8760    Anthony Wilson  Switzerland      Torreston
#
# [1000 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
#reading log data
df2=pd.read_json('C:/Users/karth/OneDrive/Desktop/REV_PROJECTS/DataSets/transaction_logs.json')
print(df2)
# Out:
#       order_id  customer_id  product_id           product_name  \
# 0            1         1731        8609  Central home & kitche
# 1            2         5539        2409             Upon sport
# 2            3         3507        1145       Across stationer
# 3            4         4826        8375    Start home & kitche
# 4            5         6538        2149             Draw beaut
# ...        ...          ...         ...                    ...
# 9995      9996         1496        9676    Range home & kitche
# 9996      9997         7288        9927               Once toy
# 9997      9998         8381        3852            Human beaut
# 9998      9999         5494        7324            Light beaut
# 9999     10000         1490        6547        Source furnitur
#
#      product_category      payment_type  qty  price            datetime  \
# 0      Home & Kitchen            Wallet   25  64216 2021-07-26 20:16:14
# ...

# %%
#EDA ON BOTH DATA SETS 
#CUSTOMER_DATA
df1.head() #first 5 rows

df1.tail() #last 5 rows
# Out:
#      customer_id    customer_name      country           city
# 995         6357   Jessica Castro     Dominica     Deannastad
# 996          244   Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490  Luis Strickland        Italy     Oneilltown
# 998         2984   Jennifer Kelly      Bahamas    Xavierville
# 999         8760   Anthony Wilson  Switzerland      Torreston

# %%
df1.tail()
# Out:
#      customer_id    customer_name      country           city
# 995         6357   Jessica Castro     Dominica     Deannastad
# 996          244   Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490  Luis Strickland        Italy     Oneilltown
# 998         2984   Jennifer Kelly      Bahamas    Xavierville
# 999         8760   Anthony Wilson  Switzerland      Torreston

# %%
#LOG_DATA
df2.head() #first 5 rows
df2.tail() #last 5 rows
# Out:
#       order_id  customer_id  product_id         product_name product_category  \
# 9995      9996         1496        9676  Range home & kitche   Home & Kitchen
# 9996      9997         7288        9927             Once toy             Toys
# 9997      9998         8381        3852          Human beaut           Beauty
# 9998      9999         5494        7324          Light beaut           Beauty
# 9999     10000         1490        6547      Source furnitur        Furniture
#
#           payment_type  qty  price            datetime ecommerce_website_name  \
# 9995            Wallet   39  61151 2024-03-17 09:06:05            www.ebay.in
# 9996  Internet Banking   44  53963 2024-06-17 08:04:22          www.amazon.in
# 9997               UPI   48  26032 2023-02-05 04:20:30       www.tatacliq.com
# 9998               UPI   17  28277 2024-02-17 03:05:57           www.etsy.com
# 9999               UPI   34  91020 2023-01-11 03:02:53       www.flipkart.com
#
# ...

# %%
df2.tail() #last 5 rows
# Out:
#       order_id  customer_id  product_id         product_name product_category  \
# 9995      9996         1496        9676  Range home & kitche   Home & Kitchen
# 9996      9997         7288        9927             Once toy             Toys
# 9997      9998         8381        3852          Human beaut           Beauty
# 9998      9999         5494        7324          Light beaut           Beauty
# 9999     10000         1490        6547      Source furnitur        Furniture
#
#           payment_type  qty  price            datetime ecommerce_website_name  \
# 9995            Wallet   39  61151 2024-03-17 09:06:05            www.ebay.in
# 9996  Internet Banking   44  53963 2024-06-17 08:04:22          www.amazon.in
# 9997               UPI   48  26032 2023-02-05 04:20:30       www.tatacliq.com
# 9998               UPI   17  28277 2024-02-17 03:05:57           www.etsy.com
# 9999               UPI   34  91020 2023-01-11 03:02:53       www.flipkart.com
#
# ...

# %%
#Information or description on dataframes
df1.info()
df1.describe() #summary of statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1000 non-null   int64
#  1   customer_name  1000 non-null   object
#  2   country        1000 non-null   object
#  3   city           1000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB
#        customer_id
# count  1000.000000
# mean   5053.297000
# std    2792.627256
# min     102.000000
# 25%    2662.000000
# 50%    5156.000000
# 75%    7395.000000
# max    9991.000000

# %%
df2.info()
df2.describe() #summary statistics for numerical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                10000 non-null  int64
#  1   customer_id             10000 non-null  int64
#  2   product_id              10000 non-null  int64
#  3   product_name            10000 non-null  object
#  4   product_category        10000 non-null  object
#  5   payment_type            10000 non-null  object
#  6   qty                     10000 non-null  int64
#  7   price                   10000 non-null  int64
#  8   datetime                10000 non-null  datetime64[ns]
#  9   ecommerce_website_name  10000 non-null  object
#  10  payment_txn_id          10000 non-null  object
#  11  payment_txn_success     10000 non-null  object
#  12  failure_reason          10000 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(7)
# ...

# %%
#Identifying missing values in customer and log data
df1.isnull().head()
# Out:
#    customer_id  customer_name  country   city
# 0        False          False    False  False
# 1        False          False    False  False
# 2        False          False    False  False
# 3        False          False    False  False
# 4        False          False    False  False

# %%
df2.isnull()
# Out:
#       order_id  customer_id  product_id  product_name  product_category  \
# 0        False        False       False         False             False
# 1        False        False       False         False             False
# 2        False        False       False         False             False
# 3        False        False       False         False             False
# 4        False        False       False         False             False
# ...        ...          ...         ...           ...               ...
# 9995     False        False       False         False             False
# 9996     False        False       False         False             False
# 9997     False        False       False         False             False
# 9998     False        False       False         False             False
# 9999     False        False       False         False             False
#
#       payment_type    qty  price  datetime  ecommerce_website_name  \
# ...

# %%
#sum of the missing values per column
df1.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# country          0
# city             0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# product_id                0
# product_name              0
# product_category          0
# payment_type              0
# qty                       0
# price                     0
# datetime                  0
# ecommerce_website_name    0
# payment_txn_id            0
# payment_txn_success       0
# failure_reason            0
# dtype: int64

# %%
#Visualizing missing values in each dataframes
#statistical plotting in python
#built on top of matplotlib
#data visualization technique that display data values in a matrix format using colors
import seaborn as sb
import matplotlib.pyplot as plt
sb.heatmap(df1.isnull(),cbar=False,cmap='viridis') #cmap=color
plt.show()

# %%
sb.heatmap(df2.isnull(),cbar=False,cmap='viridis') #cmap=color
plt.show()

# %%
#visualizing using box plots
sb.boxplot(data=df1)
plt.show()

# %%
sb.boxplot(data=df2)
plt.show()

# %%
#creating histograms for columns of a dataframe
#bins 
df1.hist(bins=30,figsize=(10,10))
plt.show()

# %%
df2.hist(bins=30,figsize=(10,10))
plt.show()

# %%
df1.columns
# Out:
# Index(['customer_id', 'customer_name', 'country', 'city'], dtype='object')

# %%
corr=df1.corr()
sb.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
corr=df2.corr()
sb.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
#pairplot for relationships
sb.pairplot(df1)
plt.show()

# %%
sb.pairplot(df2)
plt.show()

# %%
print(df1.columns)
print( )
print(df2.columns)
# Out:
# Index(['customer_id', 'customer_name', 'country', 'city'], dtype='object')
#
# Index(['order_id', 'customer_id', 'product_id', 'product_name',
#        'product_category', 'payment_type', 'qty', 'price', 'datetime',
#        'ecommerce_website_name', 'payment_txn_id', 'payment_txn_success',
#        'failure_reason'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#check if price column exists
if 'price' in df2.columns:
    #boxplot for transaction prices
    plt.figure(figsize=(10,6))
    sns.boxplot(data=df2[['price']])
    plt.title('boxplot for transaction prices')
    plt.show()
else:
    print('cloumn price doesnt exist in the dataframe')

# %%
#create a normalized database schema in python
# !pip install sqlalchemy

# %%
df1
# Out:
#      customer_id     customer_name      country           city
# 0           9780      Jessica Hart   Martinique  South William
# 1           9169         Amy Clark   Kazakhstan     Davisville
# 2           6631  Danielle Elliott      Armenia     East Danny
# 3           8772     Robin Mendoza       Uganda    Johnsonbury
# 4           8913    Abigail Miller      Namibia  Wrightchester
# ..           ...               ...          ...            ...
# 995         6357    Jessica Castro     Dominica     Deannastad
# 996          244    Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490   Luis Strickland        Italy     Oneilltown
# 998         2984    Jennifer Kelly      Bahamas    Xavierville
# 999         8760    Anthony Wilson  Switzerland      Torreston
#
# [1000 rows x 4 columns]

# %%
df2
# Out:
#       order_id  customer_id  product_id           product_name  \
# 0            1         1731        8609  Central home & kitche
# 1            2         5539        2409             Upon sport
# 2            3         3507        1145       Across stationer
# 3            4         4826        8375    Start home & kitche
# 4            5         6538        2149             Draw beaut
# ...        ...          ...         ...                    ...
# 9995      9996         1496        9676    Range home & kitche
# 9996      9997         7288        9927               Once toy
# 9997      9998         8381        3852            Human beaut
# 9998      9999         5494        7324            Light beaut
# 9999     10000         1490        6547        Source furnitur
#
#      product_category      payment_type  qty  price            datetime  \
# 0      Home & Kitchen            Wallet   25  64216 2021-07-26 20:16:14
# ...

# %%
'''Step 1: Installation
To deal with SQL in Python, we need to install the Sqlalchemy library using the below-mentioned
command by running it in cmd:

# %%
# !pip install sqlalchemy

# %%
df1.head()
# Out:
#    customer_id     customer_name     country           city
# 0         9780      Jessica Hart  Martinique  South William
# 1         9169         Amy Clark  Kazakhstan     Davisville
# 2         6631  Danielle Elliott     Armenia     East Danny
# 3         8772     Robin Mendoza      Uganda    Johnsonbury
# 4         8913    Abigail Miller     Namibia  Wrightchester

# %%
df2.head()
# Out:
#    order_id  customer_id  product_id           product_name product_category  \
# 0         1         1731        8609  Central home & kitche   Home & Kitchen
# 1         2         5539        2409             Upon sport           Sports
# 2         3         3507        1145       Across stationer       Stationery
# 3         4         4826        8375    Start home & kitche   Home & Kitchen
# 4         5         6538        2149             Draw beaut           Beauty
#
#   payment_type  qty  price            datetime ecommerce_website_name  \
# 0       Wallet   25  64216 2021-07-26 20:16:14        www.bestbuy.com
# 1         Card   34  69877 2021-08-25 03:41:32       www.flipkart.com
# 2         Card   28  35491 2024-06-21 21:39:21         www.target.com
# 3         Card   33  39540 2022-09-17 13:52:11          www.amazon.in
# 4         Card   27  80635 2022-03-09 07:58:08           www.etsy.com
#
#   payment_txn_id payment_txn_success       failure_reason
# ...

# %%
df1.columns
# Out:
# Index(['customer_id', 'customer_name', 'country', 'city'], dtype='object')

# %%
df2.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'product_name',
#        'product_category', 'payment_type', 'qty', 'price', 'datetime',
#        'ecommerce_website_name', 'payment_txn_id', 'payment_txn_success',
#        'failure_reason'],
#       dtype='object')

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
cust_df=pd.DataFrame(df1)
cust_df
# Out:
#      customer_id     customer_name      country           city
# 0           9780      Jessica Hart   Martinique  South William
# 1           9169         Amy Clark   Kazakhstan     Davisville
# 2           6631  Danielle Elliott      Armenia     East Danny
# 3           8772     Robin Mendoza       Uganda    Johnsonbury
# 4           8913    Abigail Miller      Namibia  Wrightchester
# ..           ...               ...          ...            ...
# 995         6357    Jessica Castro     Dominica     Deannastad
# 996          244    Cheryl Ramirez       Malawi  Martinezmouth
# 997         4490   Luis Strickland        Italy     Oneilltown
# 998         2984    Jennifer Kelly      Bahamas    Xavierville
# 999         8760    Anthony Wilson  Switzerland      Torreston
#
# [1000 rows x 4 columns]

# %%
trans_df=pd.DataFrame(df2)
trans_df
# Out:
#       order_id  customer_id  product_id           product_name  \
# 0            1         1731        8609  Central home & kitche
# 1            2         5539        2409             Upon sport
# 2            3         3507        1145       Across stationer
# 3            4         4826        8375    Start home & kitche
# 4            5         6538        2149             Draw beaut
# ...        ...          ...         ...                    ...
# 9995      9996         1496        9676    Range home & kitche
# 9996      9997         7288        9927               Once toy
# 9997      9998         8381        3852            Human beaut
# 9998      9999         5494        7324            Light beaut
# 9999     10000         1490        6547        Source furnitur
#
#      product_category      payment_type  qty  price            datetime  \
# 0      Home & Kitchen            Wallet   25  64216 2021-07-26 20:16:14
# ...

# %%
cust_df.columns
trans_df.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'product_name',
#        'product_category', 'payment_type', 'qty', 'price', 'datetime',
#        'ecommerce_website_name', 'payment_txn_id', 'payment_txn_success',
#        'failure_reason'],
#       dtype='object')

# %%
#transforming the customers dataframe
cust_df=cust_df[['customer_id','customer_name','country','city']]
#transforming products dataframe
products_df=pd.DataFrame({
    'product_id':trans_df['product_id'].unique(),
    'product_name':trans_df.drop_duplicates('product_id')['product_name'],
    'product_category':trans_df.drop_duplicates('product_id')['product_category']
})
products_df
# Out:
#       product_id           product_name product_category
# 0           8609  Central home & kitche   Home & Kitchen
# 1           2409             Upon sport           Sports
# 2           1145       Across stationer       Stationery
# 3           8375    Start home & kitche   Home & Kitchen
# 4           2149             Draw beaut           Beauty
# ...          ...                    ...              ...
# 9988        7708    Carry home & kitche   Home & Kitchen
# 9993        6125               Time toy             Toys
# 9994        3688          Special sport           Sports
# 9997        3852            Human beaut           Beauty
# 9998        7324            Light beaut           Beauty
#
# [6281 rows x 3 columns]

# %%
df2.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'product_name',
#        'product_category', 'payment_type', 'qty', 'price', 'datetime',
#        'ecommerce_website_name', 'payment_txn_id', 'payment_txn_success',
#        'failure_reason'],
#       dtype='object')

# %%
ecommerceweb_df=pd.DataFrame({
    'website_id':range(len(trans_df['ecommerce_website_name'].unique())),
    'website_name':trans_df['ecommerce_website_name'].unique()
})
ecommerceweb_df
# Out:
#    website_id      website_name
# 0           0   www.bestbuy.com
# 1           1  www.flipkart.com
# 2           2    www.target.com
# 3           3     www.amazon.in
# 4           4      www.etsy.com
# 5           5    www.amazon.com
# 6           6   www.walmart.com
# 7           7  www.tatacliq.com
# 8           8   www.alibaba.com
# 9           9       www.ebay.in

# %%
range(len(trans_df['ecommerce_website_name'].unique()))
# Out:
# range(0, 10)

# %%
websitename_toid=ecommerceweb_df.set_index('website_name')['website_id'].to_dict()
websitename_toid
# Out:
# {'www.bestbuy.com': 0,
#  'www.flipkart.com': 1,
#  'www.target.com': 2,
#  'www.amazon.in': 3,
#  'www.etsy.com': 4,
#  'www.amazon.com': 5,
#  'www.walmart.com': 6,
#  'www.tatacliq.com': 7,
#  'www.alibaba.com': 8,
#  'www.ebay.in': 9}

# %%
trans_df.columns
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'product_name',
#        'product_category', 'payment_type', 'qty', 'price', 'datetime',
#        'ecommerce_website_name', 'payment_txn_id', 'payment_txn_success',
#        'failure_reason'],
#       dtype='object')

# %%
trans_df['website_id']=trans_df['ecommerce_website_name'].map(websitename_toid)

# %%
trans_df['datetime']=pd.to_datetime(trans_df['datetime'])
trans_df=trans_df[['order_id','customer_id','product_id','website_id','qty','price','datetime','payment_type','payment_txn_id','payment_txn_success','failure_reason']]

# %%
# !pip install pymysql
# Out:
# ...
#      ---------------------------------------- 45.0/45.0 kB 2.2 MB/s eta 0:00:00
# ...

# %%
#mysql+pymysql specifies the datbase ('mysql' and the python dbapi ('pymysql')
#last one is the database name
engine=create_engine('mysql+pymysql://root:root@localhost/rev_projects')

# %%
cust_df
products_df
ecommerceweb_df
trans_df
# Out:
#       order_id  customer_id  product_id  website_id  qty  price  \
# 0            1         1731        8609           0   25  64216
# 1            2         5539        2409           1   34  69877
# 2            3         3507        1145           2   28  35491
# 3            4         4826        8375           3   33  39540
# 4            5         6538        2149           4   27  80635
# ...        ...          ...         ...         ...  ...    ...
# 9995      9996         1496        9676           9   39  61151
# 9996      9997         7288        9927           3   44  53963
# 9997      9998         8381        3852           7   48  26032
# 9998      9999         5494        7324           4   17  28277
# 9999     10000         1490        6547           1   34  91020
#
#                 datetime      payment_type payment_txn_id payment_txn_success  \
# 0    2021-07-26 20:16:14            Wallet       a395e8c7                   N
# ...

# %%
cust_df.to_sql('customers',con=engine,if_exists='replace',index=False)
# Out:
# 1000

# %%
products_df.to_sql('products',con=engine,if_exists='replace',index=False)
# Out:
# 6281

# %%
ecommerceweb_df.to_sql('ecommerce_websites',con=engine,if_exists='replace',index=False)
# Out:
# 10

# %%
trans_df.to_sql('transactions',con=engine,if_exists='replace',index=False)
# Out:
# 10000

# %%
import mysql.connector
db1=mysql.connector.connect(
    host='localhost',
    user='root',
    password='root',
    database='rev_projects')

# %%
cursor=db1.cursor()
cursor.execute('show tables')
res=cursor.fetchall()
for i in res:
    print(i)
# Out:
# ('customers',)
# ('ecommerce_websites',)
# ('products',)
# ('transactions',)

# %%
cursor.execute('select * from ecommerce_websites')
#rows=cursor.fetchmany(size=4)
res=cursor.fetchall()
for _  in res:
    print(_)
# Out:
# (0, 'www.bestbuy.com')
# (1, 'www.flipkart.com')
# (2, 'www.target.com')
# (3, 'www.amazon.in')
# (4, 'www.etsy.com')
# (5, 'www.amazon.com')
# (6, 'www.walmart.com')
# (7, 'www.tatacliq.com')
# (8, 'www.alibaba.com')
# (9, 'www.ebay.in')

# %%
cursor.execute('select * from transactions limit 2')
#rows=cursor.fetchmany(size=4)
res=cursor.fetchall() 
for _  in res:
    print(_)
# Out:
# (1, 1731, 8609, 0, 25, 64216, datetime.datetime(2021, 7, 26, 20, 16, 14), 'Wallet', 'a395e8c7', 'N', 'Card Expired')
# (2, 5539, 2409, 1, 34, 69877, datetime.datetime(2021, 8, 25, 3, 41, 32), 'Card', 'b40791f8', 'N', 'Invalid CVV')
